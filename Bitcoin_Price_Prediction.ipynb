# %% [markdown]
# In this notebook we want to predict Bitcoin price using python and machin learning (LSTM network).
#
# So first of all we will import the libraries that we want to use in this notebook

# %%
import math
# %pip install pandas_datareader
import pandas_datareader as web
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 2.6 MB/s eta 0:00:01
# Collecting lxml
#   Downloading lxml-5.4.0-cp39-cp39-macosx_10_9_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 19.3 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from pandas_datareader) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from pandas_datareader) (2.32.3)
# Requirement already satisfied: tzdata>=2022.7 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23->pandas_datareader) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23->pandas_datareader) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23->pandas_datareader) (1.26.4)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pandas_datareader) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pandas_datareader) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pandas_datareader) (2025.4.26)
# Requirement already satisfied: idna<4,>=2.5 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pandas_datareader) (3.10)
# Installing collected packages: lxml, pandas-datareader
# Successfully installed lxml-5.4.0 pandas-datareader-0.10.0
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now Let's import our Dataframe. I used the `pd.DataReader()` library to import my dataframe. It's supper easy and fun :)

# %%
# Data Frame did import from google colab. 
# You can upload the data frame on your google drive and mounting the drive with the google clab
df = web.DataReader('BTC-USD', data_source='yahoo', start='2014-01-01', end='2022-01-10')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 # Data Frame did import from google colab.
#       2 # You can upload the data frame on your google drive and mounting the drive with the google clab
# ----> 3 df = web.DataReader('BTC-USD', data_source='yahoo', start='2014-01-01', end='2022-01-10')
#       4 df.head()
#
# NameError: name 'web' is not defined

# %%
# Checking the shape of our original data frame
df.shape
# Out:
# (2674, 6)

# %% [markdown]
# Now let's plot our close price only. We wanna use the **dailty close price** of Bitcoin for our model in this notebook so we only plot **close price**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))
plt.title('Close Price', fontsize=24)
plt.plot(df['Close'])
plt.xlabel('Data', fontsize=18)
plt.ylabel('USD', fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(16,8))
#       4 plt.title('Close Price', fontsize=24)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# So as we want to work only with Close Price, let's use `.filter` methode.
# then we will import the values of the close price column in `data` variable to `dataset` variable.

# %%
# Import the necessary library to fetch the data
import pandas_datareader as web

# Re-import the dataframe
df = web.DataReader('BTC-USD', data_source='yahoo', start='2014-01-01', end='2022-01-10')

# Create a new dataframe with only Close Price
data = df.filter(['Close'])
# Convert the dataframe to numpy array
dataset = data.values
# Get the number of rows to train the model on. we need this number to create our train and test sets
# math.ceil will round up the number
training_data_len = math.ceil(len(dataset) * .8) # We are using %80 of the data for training
training_data_len
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Import the necessary library to fetch the data
# ----> 2 import pandas_datareader as web
#       4 # Re-import the dataframe
#       5 df = web.DataReader('BTC-USD', data_source='yahoo', start='2014-01-01', end='2022-01-10')
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %% [markdown]
# Now that we have our close price values in a seprated dataframe we can start normalization our data.

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Scale the data
# ----> 2 scaler = MinMaxScaler(feature_range=(0,1))
#       3 scaled_data = scaler.fit_transform(dataset)
#       4 scaled_data
#
# NameError: name 'MinMaxScaler' is not defined

# %% [markdown]
# In this case, we can't use `train_test_split` function, because we need our train and test sets to be **Sequential Data**. LSTM network needs to have the *last output values* of network layer for the *input of the next layer* of network. So we can't use `train_test_split` and randomize our train/test data.

# %% [markdown]
# Our model will predict the price by looking the last 60 days of price. this will help our model to predict a better price and not just a random number that would have less than %50 accuracy.

# %%
# Creat the training dataset
train_data = scaled_data[0:training_data_len, :]
# Split the data into X_train and y_train data sets
X_train = []
y_train = []

for i in range(60, len(train_data)):
  X_train.append(train_data[i-60: i, 0])
  y_train.append(train_data[i, 0])


  if i <= 60:
    print(X_train)
    print(y_train)
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Creat the training dataset
# ----> 2 train_data = scaled_data[0:training_data_len, :]
#       3 # Split the data into X_train and y_train data sets
#       4 X_train = []
#
# NameError: name 'scaled_data' is not defined

# %%
len(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 len(X_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# So now X_train has 2083 array which any of them contains 60 days of price in them and y_train contains 2083 days of price which is the price of the last 60 days.

# %% [markdown]
# LSTM model needs the data to be an *array*. So here we will convert X_train and y_train to an array list.

# %%
# Convert the X_train and y_train to numpy array
X_train, y_train = np.array(X_train), np.array(y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Convert the X_train and y_train to numpy array
# ----> 2 X_train, y_train = np.array(X_train), np.array(y_train)
#
# NameError: name 'np' is not defined

# %%
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 X_train.shape
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# By the way, LSTM needs the data to be inputet by 3 dimension. So we will reshape X_train to a 3-dim array

# %%
# Reshape the data because LSTM needs 3 dim
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1)) # we make it like pros. it wanna say "np.reshape(X_train, (2083, 60, 1))"
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Reshape the data because LSTM needs 3 dim
# ----> 2 X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1)) # we make it like pros. it wanna say "np.reshape(X_train, (2083, 60, 1))"
#       3 X_train.shape
#
# NameError: name 'np' is not defined

# %% [markdown]
# Now that we finish creating our train data, we can create our *test data* (Just like how we did with train data).

# %%
# Create the testing dataset
# Create a new array containing scaled values from index 2083
test_data = scaled_data[training_data_len - 60 : , :]

#Create the data sets X_test and y_test
X_test = []
y_test = dataset[training_data_len : , :]
for i in range(60, len(test_data)):
  X_test.append(test_data[i-60 : i, 0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Create the testing dataset
#       2 # Create a new array containing scaled values from index 2083
# ----> 3 test_data = scaled_data[training_data_len - 60 : , :]
#       5 #Create the data sets X_test and y_test
#       6 X_test = []
#
# NameError: name 'scaled_data' is not defined

# %%
# Convert the data to a numpy array 
X_test = np.array(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Convert the data to a numpy array
# ----> 2 X_test = np.array(X_test)
#
# NameError: name 'np' is not defined

# %%
# Reshape the test data
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Reshape the test data
# ----> 2 X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
#
# NameError: name 'np' is not defined

# %% [markdown]
# Here we getting to the fun part, **Creating the model**
#
# We are using 2 layers of LSTM and 2 layers of Dense. Our first LSTM layer has `return_sequence=True` because our first and second layers are LSTM and we have to pass the output of the first layer to the second layer. (Again: **LSTM is a Network for Sequential Data**)

# %% [markdown]
# Our last layer only has one unit in it while we need only one number (one price) to predict.

# %%
# Build LSTM model
# Ensure TensorFlow is installed
# %pip install tensorflow
import tensorflow as tf
tf.random.set_seed(42)

model_1 = Sequential()
model_1.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1))) # we made it like pros ;) , the simple form is "input_shape(60, 1)""
model_1.add(LSTM(50, return_sequences=False))
model_1.add(Dense(25))
model_1.add(Dense(1))
# Out:
# 25409.36s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.16.2-cp39-cp39-macosx_10_15_x86_64.whl (259.5 MB)
#      |████████████████████████████████| 259.5 MB 10 kB/s s eta 0:00:01  |▏                               | 1.6 MB 2.6 MB/s eta 0:01:39     |▋                               | 4.9 MB 2.6 MB/s eta 0:01:37     |██                              | 15.4 MB 12.3 MB/s eta 0:00:20     |█████▎                          | 42.5 MB 18.6 MB/s eta 0:00:12     |█████▎                          | 42.9 MB 18.6 MB/s eta 0:00:12     |██████▉                         | 55.2 MB 9.8 MB/s eta 0:00:21     |██████▉                         | 55.5 MB 9.8 MB/s eta 0:00:21     |███████                         | 56.0 MB 9.8 MB/s eta 0:00:21     |███████▍                        | 59.5 MB 9.8 MB/s eta 0:00:21     |████████▊                       | 71.2 MB 7.2 MB/s eta 0:00:27     |█████████▊                      | 78.8 MB 9.1 MB/s eta 0:00:20     |████████████                    | 97.3 MB 6.3 MB/s eta 0:00:26████▋                   | 102.4 MB 8.6 MB/s eta 0:00:19     |████████████▊                   | 103.1 MB 8.6 MB/s eta 0:00:19     |█████████████                   | 104.6 MB 8.6 MB/s eta 0:00:18     |█████████████▌                  | 109.6 MB 7.0 MB/s eta 0:00:22     |██████████████▋                 | 118.6 MB 5.3 MB/s eta 0:00:27     |███████████████▉                | 128.1 MB 5.3 MB/s eta 0:00:25     |██████████████████▎             | 148.6 MB 7.6 MB/s eta 0:00:15     |██████████████████▌             | 149.8 MB 7.6 MB/s eta 0:00:15     |██████████████████▋             | 151.1 MB 7.6 MB/s eta 0:00:15  |███████████████████▎            | 156.1 MB 4.5 MB/s eta 0:00:24     |████████████████████▋           | 166.8 MB 8.7 MB/s eta 0:00:11     |████████████████████▉           | 168.8 MB 8.7 MB/s eta 0:00:11     |█████████████████████▋          | 175.7 MB 5.1 MB/s eta 0:00:17     |██████████████████████▍         | 181.4 MB 5.1 MB/s eta 0:00:16     |███████████████████████▎        | 189.0 MB 9.8 MB/s eta 0:00:08     |█████████████████████████▏      | 203.8 MB 10.5 MB/s eta 0:00:06     |██████████████████████████▌     | 215.1 MB 9.1 MB/s eta 0:00:05     |███████████████████████████▎    | 221.2 MB 6.7 MB/s eta 0:00:06     |████████████████████████████▏   | 228.3 MB 6.4 MB/s eta 0:00:05     |████████████████████████████▌   | 231.1 MB 6.8 MB/s eta 0:00:05     |█████████████████████████████▏  | 237.0 MB 6.8 MB/s eta 0:00:04
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp39-cp39-macosx_10_14_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 13.2 MB/s eta 0:00:01
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.1 MB/s eta 0:00:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.71.0-cp39-cp39-macosx_10_14_universal2.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 70 kB/s s eta 0:00:01    |███████████████████▍            | 6.9 MB 18.0 MB/s eta 0:00:01
# Collecting keras>=3.0.0
#   Downloading keras-3.9.2-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 7.6 MB/s eta 0:00:01
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.17.2-cp39-cp39-macosx_10_9_x86_64.whl (38 kB)
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-macosx_10_9_x86_64.whl (26.5 MB)
#      |████████████████████████████████| 26.5 MB 8.1 MB/s eta 0:00:011    |█▋                              | 1.4 MB 12.2 MB/s eta 0:00:03     |██████████████████████████████▊ | 25.5 MB 8.1 MB/s eta 0:00:01
# Collecting numpy<2.0.0,>=1.23.5
#   Downloading numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 10.0 MB/s eta 0:00:01     |███████████████████████▍        | 15.1 MB 10.0 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.13.2)
# Collecting tensorboard<2.17,>=2.16
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 9.7 MB/s eta 0:00:01     |█████████████████████▋          | 3.7 MB 9.7 MB/s eta 0:00:01
# Collecting flatbuffers>=23.5.26
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.25.7-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
#      |████████████████████████████████| 394 kB 5.2 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Collecting h5py>=3.10.0
#   Downloading h5py-3.13.0-cp39-cp39-macosx_10_9_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 10.9 MB/s eta 0:00:01     |██████████████████▌             | 2.0 MB 10.9 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 2.2 MB/s  eta 0:00:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 491 kB/s eta 0:00:01
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 10.0 MB/s eta 0:00:01
# Collecting ml-dtypes~=0.3.1
#   Downloading ml_dtypes-0.3.2-cp39-cp39-macosx_10_9_universal2.whl (389 kB)
#      |████████████████████████████████| 389 kB 10.5 MB/s eta 0:00:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Collecting namex
#   Downloading namex-0.0.9-py3-none-any.whl (5.8 kB)
# Collecting rich
#   Downloading rich-14.0.0-py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 6.6 MB/s eta 0:00:01
# Collecting optree
#   Downloading optree-0.15.0-cp39-cp39-macosx_10_9_universal2.whl (609 kB)
#      |████████████████████████████████| 609 kB 10.8 MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 4.9 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 8.8 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 5.8 MB/s eta 0:00:011
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.2-cp39-cp39-macosx_10_9_universal2.whl (201 kB)
#      |████████████████████████████████| 201 kB 3.4 MB/s eta 0:00:01
# Collecting markdown>=2.6.8
#   Downloading markdown-3.8-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 5.0 MB/s eta 0:00:01
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 5.0 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 6.8 MB/s eta 0:00:01     |█▋                              | 245 kB 6.8 MB/s eta 0:00:01     |███████████████████████▊        | 3.6 MB 6.8 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow) (3.21.0)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-3.0.2-cp39-cp39-macosx_10_9_universal2.whl (14 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/skylerlake/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.0.0->tensorflow) (2.19.1)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 4.5 MB/s eta 0:00:011
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mdurl, numpy, MarkupSafe, markdown-it-py, werkzeug, urllib3, tensorboard-data-server, rich, protobuf, optree, namex, ml-dtypes, markdown, idna, h5py, grpcio, charset-normalizer, certifi, absl-py, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorboard, requests, opt-einsum, libclang, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed MarkupSafe-3.0.2 absl-py-2.2.2 astunparse-1.6.3 certifi-2025.4.26 charset-normalizer-3.4.2 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.71.0 h5py-3.13.0 idna-3.10 keras-3.9.2 libclang-18.1.1 markdown-3.8 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.3.2 namex-0.0.9 numpy-1.26.4 opt-einsum-3.4.0 optree-0.15.0 protobuf-4.25.7 requests-2.32.3 rich-14.0.0 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.2 tensorflow-io-gcs-filesystem-0.37.1 termcolor-3.1.0 urllib3-2.4.0 werkzeug-3.1.3 wrapt-1.17.2
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# 2025-05-14 00:49:17.013222: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/skylerlake/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 4
#       1 # Build LSTM model
#       2 # Ensure TensorFlow is installed
#       3 get_ipython().run_line_magic('pip', 'install tensorflow')
# ----> 4 import tensorflow as tf
#       5 tf.random.set_seed(42)
#       7 model_1 = Sequential()
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/__init__.py:462
#     460     importlib.import_module("tf_keras.src.optimizers")
#     461   else:
# --> 462     importlib.import_module("keras.src.optimizers")
#     463 except (ImportError, AttributeError):
#     464   pass
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/api/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/api/activations/__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize
#       8 from keras.src.activations import get
#       9 from keras.src.activations import serialize
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/activations/__init__.py:33
#      31 from keras.src.activations.activations import threshold
#      32 from keras.src.api_export import keras_export
# ---> 33 from keras.src.saving import object_registration
#      34 from keras.src.saving import serialization_lib
#      36 ALL_OBJECTS = {
#      37     relu,
#      38     leaky_relu,
#    (...)
#      65     sparsemax,
#      66 }
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/saving/__init__.py:7
#       5 from keras.src.saving.object_registration import get_registered_object
#       6 from keras.src.saving.object_registration import register_keras_serializable
# ----> 7 from keras.src.saving.saving_api import load_model
#       8 from keras.src.saving.serialization_lib import deserialize_keras_object
#       9 from keras.src.saving.serialization_lib import serialize_keras_object
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/saving/saving_api.py:7
#       4 from absl import logging
#       6 from keras.src.api_export import keras_export
# ----> 7 from keras.src.legacy.saving import legacy_h5_format
#       8 from keras.src.saving import saving_lib
#       9 from keras.src.utils import file_utils
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/legacy/saving/legacy_h5_format.py:13
#      11 from keras.src.legacy.saving import json_utils
#      12 from keras.src.legacy.saving import saving_options
# ---> 13 from keras.src.legacy.saving import saving_utils
#      14 from keras.src.saving import object_registration
#      15 from keras.src.utils import io_utils
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/legacy/saving/saving_utils.py:10
#       8 from keras.src import losses
#       9 from keras.src import metrics as metrics_module
# ---> 10 from keras.src import models
#      11 from keras.src import optimizers
#      12 from keras.src import tree
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/models/__init__.py:1
# ----> 1 from keras.src.models.functional import Functional
#       2 from keras.src.models.model import Model
#       3 from keras.src.models.sequential import Sequential
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/models/functional.py:16
#      14 from keras.src.legacy.saving import saving_utils
#      15 from keras.src.legacy.saving import serialization as legacy_serialization
# ---> 16 from keras.src.models.model import Model
#      17 from keras.src.ops.function import Function
#      18 from keras.src.ops.function import _build_map
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/models/model.py:12
#      10 from keras.src.models.variable_mapping import map_saveable_variables
#      11 from keras.src.saving import saving_api
# ---> 12 from keras.src.trainers import trainer as base_trainer
#      13 from keras.src.utils import summary_utils
#      14 from keras.src.utils import traceback_utils
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/trainers/trainer.py:14
#      12 from keras.src.trainers.compile_utils import CompileLoss
#      13 from keras.src.trainers.compile_utils import CompileMetrics
# ---> 14 from keras.src.trainers.data_adapters import data_adapter_utils
#      15 from keras.src.utils import python_utils
#      16 from keras.src.utils import traceback_utils
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/trainers/data_adapters/__init__.py:4
#       1 import types
#       3 from keras.src.distribution import distribution_lib
# ----> 4 from keras.src.trainers.data_adapters import array_data_adapter
#       5 from keras.src.trainers.data_adapters import data_adapter
#       6 from keras.src.trainers.data_adapters import py_dataset_adapter
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:7
#       4 import numpy as np
#       6 from keras.src import tree
# ----> 7 from keras.src.trainers.data_adapters import array_slicing
#       8 from keras.src.trainers.data_adapters import data_adapter_utils
#       9 from keras.src.trainers.data_adapters.data_adapter import DataAdapter
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/trainers/data_adapters/array_slicing.py:12
#       9 from keras.src.utils.module_utils import tensorflow as tf
#      11 try:
# ---> 12     import pandas
#      13 except ImportError:
#      14     pandas = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/__init__.py:49
#      46 # let init-time option registration happen
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#      52     Int8Dtype,
#      53     Int16Dtype,
#      54     Int32Dtype,
#      55     Int64Dtype,
#      56     UInt8Dtype,
#      57     UInt16Dtype,
#      58     UInt32Dtype,
#      59     UInt64Dtype,
#      60     Float32Dtype,
#      61     Float64Dtype,
#      62     CategoricalDtype,
#      63     PeriodDtype,
#      64     IntervalDtype,
#      65     DatetimeTZDtype,
#      66     StringDtype,
#      67     BooleanDtype,
#      68     # missing
#      69     NA,
#      70     isna,
#      71     isnull,
#      72     notna,
#      73     notnull,
#      74     # indexes
#      75     Index,
#      76     CategoricalIndex,
#      77     RangeIndex,
#      78     MultiIndex,
#      79     IntervalIndex,
#      80     TimedeltaIndex,
#      81     DatetimeIndex,
#      82     PeriodIndex,
#      83     IndexSlice,
#      84     # tseries
#      85     NaT,
#      86     Period,
#      87     period_range,
#      88     Timedelta,
#      89     timedelta_range,
#      90     Timestamp,
#      91     date_range,
#      92     bdate_range,
#      93     Interval,
#      94     interval_range,
#      95     DateOffset,
#      96     # conversion
#      97     to_numeric,
#      98     to_datetime,
#      99     to_timedelta,
#     100     # misc
#     101     Flags,
#     102     Grouper,
#     103     factorize,
#     104     unique,
#     105     value_counts,
#     106     NamedAgg,
#     107     array,
#     108     Categorical,
#     109     set_eng_float_format,
#     110     Series,
#     111     DataFrame,
#     112 )
#     114 from pandas.core.dtypes.dtypes import SparseDtype
#     116 from pandas.tseries.api import infer_freq
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# File interval.pyx:1, in init pandas._libs.interval()
#
# File hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File missing.pyx:1, in init pandas._libs.missing()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/tslibs/__init__.py:68
#      62 from pandas._libs.tslibs.offsets import (
#      63     BaseOffset,
#      64     Tick,
#      65     to_offset,
#      66 )
#      67 from pandas._libs.tslibs.parsing import guess_datetime_format
# ---> 68 from pandas._libs.tslibs.period import (
#      69     IncompatibleFrequency,
#      70     Period,
#      71 )
#      72 from pandas._libs.tslibs.timedeltas import (
#      73     Timedelta,
#      74     delta_to_nanoseconds,
#      75     ints_to_pytimedelta,
#      76 )
#      77 from pandas._libs.tslibs.timestamps import Timestamp
#
# File <frozen importlib._bootstrap>:398, in parent(self)
#
# KeyboardInterrupt:

# %%
# Compile the model
model_1.compile(optimizer='adam', loss='mse')

# %% [markdown]
# We will store the steps of each epochs in `history` variable. We are doing this to ploting the loss and finding the best number of epochs to avoid overfiting training.
#
# Here we make a variable call `callback` which has the job to stop training the model whenever the *loss* is no longer decreasing.
#
# (for more detail check the [EarlyStopping](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping) library)

# %%
# Train the model
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=2)
history = model_1.fit(X_train, y_train, batch_size=1, epochs=10)
# Out:
# Epoch 1/10
# 2080/2080 [==============================] - 63s 28ms/step - loss: 2.0942e-04
# Epoch 2/10
# 2080/2080 [==============================] - 59s 28ms/step - loss: 8.7422e-05
# Epoch 3/10
# 2080/2080 [==============================] - 59s 28ms/step - loss: 6.1341e-05
# Epoch 4/10
# 2080/2080 [==============================] - 58s 28ms/step - loss: 6.4308e-05
# Epoch 5/10
# 2080/2080 [==============================] - 60s 29ms/step - loss: 5.6123e-05
# Epoch 6/10
# 2080/2080 [==============================] - 60s 29ms/step - loss: 4.3052e-05
# Epoch 7/10
# 2080/2080 [==============================] - 59s 29ms/step - loss: 4.6994e-05
# Epoch 8/10
# 2080/2080 [==============================] - 59s 28ms/step - loss: 4.5502e-05
# Epoch 9/10
# 2080/2080 [==============================] - 58s 28ms/step - loss: 4.1160e-05
# Epoch 10/10
# 2080/2080 [==============================] - 58s 28ms/step - loss: 4.1792e-05

# %%
# Get the model_1 predicted price values 
predictions_1 = model_1.predict(X_test)
predictions_1 = scaler.inverse_transform(predictions_1)
len(predictions_1)
# Out:
# 534

# %%
# Get the root mean squared error (RMSE) for model_1
rmse = np.sqrt(np.mean(predictions_1 - y_test)**2)
rmse
# Out:
# 3304.1335988705523

# %%
# Let's plot the history of model_1 and see what's going on
historyForPlot = pd.DataFrame(history.history)
historyForPlot.index += 1 # we plus 1 to the number of indexing so our epochs Plot picture will be counting from 1 not 0.
historyForPlot.plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# As we can see, on epochs 6 and 10 we have the less loss and best scores. So we can train our model again with 6 epochs to see which one is better fiting.

# %%
# Train the model again with 7 epochs
# but first we need to create another model so we can compare them together

# building LSTM model_2
tf.random.set_seed(42)

model_2 = Sequential()
model_2.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1))) # we made it like pros ;) | the simple form is "input_shape(60, 1)
model_2.add(LSTM(50, return_sequences=False))
model_2.add(Dense(25))
model_2.add(Dense(1))

# Compile model_2
model_2.compile(optimizer='Adam', loss='mse')

# Fit model_2
history_2 = model_2.fit(X_train, y_train, batch_size=1, epochs=6)
# Out:
# Epoch 1/6
# 2080/2080 [==============================] - 64s 29ms/step - loss: 2.0942e-04
# Epoch 2/6
# 2080/2080 [==============================] - 60s 29ms/step - loss: 8.7422e-05
# Epoch 3/6
# 2080/2080 [==============================] - 60s 29ms/step - loss: 6.1341e-05
# Epoch 4/6
# 2080/2080 [==============================] - 60s 29ms/step - loss: 6.4308e-05
# Epoch 5/6
# 2080/2080 [==============================] - 60s 29ms/step - loss: 5.6123e-05
# Epoch 6/6
# 2080/2080 [==============================] - 60s 29ms/step - loss: 4.3052e-05

# %%
# Get the model_2 predicted price values 
predictions_2 = model_2.predict(X_test)
predictions_2 = scaler.inverse_transform(predictions_2)
len(predictions_2)
# Out:
# 534

# %%
# Get the root mean squared error (RMSE) for model_2
rmse_2 = np.sqrt(np.mean(predictions_2 - y_test)**2)
rmse_2
# Out:
# 5525.02767475714

# %% [markdown]
# Now let's see what did our models with predictions and compare our 2 models together:

# %%
# Plot the data
train = data[:training_data_len]

#data for model_1
valid_1 = data[training_data_len:]
valid_1['Predictions'] = predictions_1

# data for model_2
valid_2 = data[training_data_len:]
valid_2['Predictions'] = predictions_2

# Visualized the data 
#model_1
plt.figure(figsize=(14, 10))
plt.subplot(2, 1, 1)
plt.title('Model_1 with 10 epochs')
plt.xlabel('Data', fontsize=18)
plt.ylabel('Close Price USD', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid_1[['Close', 'Predictions']])

plt.legend(['Train', 'Valid', 'Predictions'], loc='upper left')

#model_2
plt.subplot(2, 1, 2)
plt.title('Model_2 with 6 epochs')
plt.xlabel('Data', fontsize=18)
plt.ylabel('Close Price USD', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid_2[['Close', 'Predictions']])

plt.legend(['Train', 'Valid', 'Predictions'], loc='upper left')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=1, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# It seem's our model_1 has a better predictions than the model_2. So please keep in mind that never choose a model to use, without ploting the result ;)

# %% [markdown]
# Now it's time to predict a future day price which is not in train or test set. In other words we want to predict a price out of the dataframe which is the price of today.
#
# So first we need to create a new variable `last_60_days` and use it to predict the today price of Bitcoin. This way we can create a new test set to creating the price of last 60 days from today (today is 1/15/2022).

# %%
#Get the last 60 day closing price values and convert the datadrame to an array
last_60_days = data[-60:].values
# Scale the data to be values between 0 and 1
last_60_days_scaled = scaler.fit_transform(last_60_days)
# create an empty list
new_X_test = []
# Append the past 60 days
new_X_test.append(last_60_days_scaled)
# Convert the X_test data set to a numpy array
new_X_test = np.array(new_X_test)
# Reshape the data 
new_X_test = np.reshape(new_X_test, (new_X_test.shape[0], new_X_test.shape[1], 1))
# Get the predicted scaled price
pred_price = model_1.predict(new_X_test)
# Undo the scaling
pred_price = scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# [[42736.152]]

# %% [markdown]
# Here is the today price of bitcoin:
#
# ![Bitcoin price.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# It seems our model did a good job with prediction today price. We might upgrade this model in the future together.
#
# You can improve the model that we write together by doing these steps:
#
# * Increase or decrease the hidden layers
# * Increase or decrease the Units per each layer
# * Using other types of layer or changing the activation function of the layers
# * Train more the model with diffrent batch size and see what will happen
#
# Don't forget that never change many items in your model, because you can't figure it out which of those changes will couse the improvment on to your model. And always using ploting and storing the history of training steps to see what is going on.

# %% [markdown]
# So here is the end of this notebook. I hope you did enjoy and learned something new.
#
# Don't forget to give me a star if you like this model ;)
